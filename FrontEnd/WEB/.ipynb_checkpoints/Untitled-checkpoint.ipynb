# %%
import datetime
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2
import pandas as pd
# %matplotlib inline
import scipy.ndimage as ndimage
import numpy as np
from sys import stdout

import passearch_model
import diff_maps
reload(diff_maps)
# Out:
# <module 'diff_maps' from '/Users/jgabor/NEW_WORKDIR/INSIGHT/Passearch/BackEnd/Explore/diff_maps.pyc'>

# %%
im = np.load('junk.npy')

# %%
plt.imshow(im)

# %%
im = np.load('junk.npy')

# %%
plt.imshow(im)

# %%
np.nanargmin(im)
# Out:
# 147
